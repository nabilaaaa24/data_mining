# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilaaaa24/data_mining/blob/main/Praktikum_Modul_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kegiatan 1 - EDA
#
# 1. Menampilkan metadata dataset secara lengkap disertai penjelasan ringkas
# 2. Menganalisis business problem/question (minimal 5)
# 3. Menampilkan analisis deskriptif statistik / data outlier

# %% [markdown]
# Kegiatan 2 - Visualisasi
#
# 1. Membuat visualisasi data sesuai kategori, bisa comparison/ relationship/ distribution/ com sebanyak 3 grafik
#
# 2. Berikan penjelasan singkat mengenai grafik yang telah dibuat.

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/smartphones.csv')
df
# Out:
# Mounted at /content/drive
#     brand_name                                      model   price  avg_rating  \
# 0        apple                            Apple iPhone 11   38999         7.3
# 1        apple                    Apple iPhone 11 (128GB)   46999         7.5
# 2        apple                    Apple iPhone 11 Pro Max  109900         7.7
# 3        apple                            Apple iPhone 12   51999         7.4
# 4        apple                    Apple iPhone 12 (128GB)   55999         7.5
# ..         ...                                        ...     ...         ...
# 975     xiaomi                    Xiaomi Redmi Note 9 Pro   13999         7.5
# 976     xiaomi  Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)   14439         7.7
# 977     xiaomi                Xiaomi Redmi Note 9 Pro Max   16490         8.0
# 978        zte                               ZTE Axon 30S   19999         8.2
# 979        zte                       ZTE Axon 40 Ultra 5G   61990         8.9
#
# ...

# %% [markdown]
# 1. Menampilkan metadata dataset secara lengkap disertai penjelasan ringkas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   avg_rating                 879 non-null    float64
#  4   5G_or_not                  980 non-null    int64
#  5   processor_brand            960 non-null    object
#  6   num_cores                  974 non-null    float64
#  7   processor_speed            938 non-null    float64
#  8   battery_capacity           969 non-null    float64
#  9   fast_charging_available    980 non-null    int64
#  10  fast_charging              769 non-null    float64
#  11  ram_capacity               980 non-null    int64
#  12  internal_memory            980 non-null    int64
# ...

# %%
null_columns = df.columns[df.isnull().any()]
print("Kolom dengan nilai null:", null_columns)

null_count = df[null_columns].isnull().sum()
print("Jumlah nilai null untuk setiap kolom:")
print(null_count)
# Out:
# Kolom dengan nilai null: Index(['avg_rating', 'processor_brand', 'num_cores', 'processor_speed',
#        'battery_capacity', 'fast_charging', 'os', 'primary_camera_front'],
#       dtype='object')
# Jumlah nilai null untuk setiap kolom:
# avg_rating              101
# processor_brand          20
# num_cores                 6
# processor_speed          42
# battery_capacity         11
# fast_charging           211
# os                       14
# primary_camera_front      5
# dtype: int64

# %% [markdown]
# 2. Menganalisis business problem/question (minimal 5)

# %% [markdown]
# 1. Bagaimana distribusi harga smartphone di dalam dataset?

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribusi Harga Smartphone (Histogram)')
plt.xlabel('Harga')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# 2. Apakah merek tertentu mendominasi pasar smartphone?

# %%
brand_counts = df['brand_name'].value_counts()

plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar')
plt.title('Distribusi Merek Smartphone dalam Dataset')
plt.xlabel('Merek Smartphone')
plt.ylabel('Frekuensi')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# 3. Bagaimana perbandingan rata-rata harga smartphone antara merek-merek yang ada di pasaran?

# %%
average_price_by_brand = df.groupby('brand_name')['price'].mean()
print(average_price_by_brand)
average_price_by_brand_sorted = average_price_by_brand.sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=average_price_by_brand_sorted.index, y=average_price_by_brand_sorted.values)
plt.title('Perbandingan Rata-rata Harga Smartphone Berdasarkan Merek')
plt.xlabel('Merek Smartphone')
plt.ylabel('Rata-rata Harga')
plt.xticks(rotation=60)
plt.show()
# Out:
# brand_name
# apple         95966.521739
# asus          74709.428571
# blackview      8990.000000
# blu           14990.000000
# cat           14999.000000
# cola          14999.000000
# doogee        30499.000000
# duoqin         9990.000000
# gionee         6896.000000
# google        44332.571429
# honor         30301.846154
# huawei        80177.250000
# ikall          7632.333333
# infinix       14664.793103
# iqoo          30301.875000
# itel           5811.000000
# jio            7159.250000
# lava          11246.750000
# leeco         10999.000000
# leitz        124990.000000
# lenovo        53494.500000
# letv           6165.666667
# lg            63329.333333
# lyf            3940.000000
# micromax       6929.333333
# motorola      24099.923077
# nokia         24630.769231
# nothing       31195.400000
# nubia         49827.833333
# oneplus       35858.571429
# oppo          29650.034091
# oukitel       26293.000000
# poco          18479.195122
# realme        17461.422680
# ...

# %% [markdown]
# 4. Apakah terdapat korelasi antara rating pengguna dan harga smartphone?

# %%
df_clean = df.dropna(subset=['battery_capacity', 'price'])

plt.figure(figsize=(10, 6))
sns.scatterplot(x='battery_capacity', y='price', data=df_clean)
plt.title('Hubungan Antara Kapasitas Baterai dan Harga Smartphone')
plt.xlabel('Kapasitas Baterai (mAh)')
plt.ylabel('Harga')
plt.show()

correlation = df_clean['battery_capacity'].corr(df_clean['price'])
print("Korelasi antara kapasitas baterai dan harga smartphone:", correlation)
# Out:
# Korelasi antara kapasitas baterai dan harga smartphone: -0.15923204381244005

# %% [markdown]
# 5. Bagaimana distribusi ukuran penyimpanan (storage) pada smartphone?

# %%
storage_counts = df['internal_memory'].value_counts()
print("Internal Memory")
print(storage_counts)

plt.figure(figsize=(10, 6))
plt.hist(df['internal_memory'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribusi Ukuran Penyimpanan Smartphone')
plt.xlabel('Ukuran Penyimpanan (GB)')
plt.ylabel('Frekuensi')
plt.grid(True)
plt.show()
# Out:
# Internal Memory
# 128     523
# 64      193
# 256     157
# 32       67
# 512      22
# 16       12
# 1024      5
# 8         1
# Name: internal_memory, dtype: int64

# %% [markdown]
# 6. Apakah ada hubungan antara rating kamera dan rating umum smartphone?

# %%
df_clean = df.dropna(subset=['avg_rating', 'primary_camera_rear'])

plt.figure(figsize=(10, 6))
sns.scatterplot(x='primary_camera_rear', y='avg_rating', data=df_clean)
plt.title('Hubungan Antara Rating Kamera dan Rating Umum Smartphone')
plt.xlabel('Rating Kamera')
plt.ylabel('Rating Umum')
plt.show()

correlation = df_clean['primary_camera_rear'].corr(df_clean['avg_rating'])
print("Korelasi antara rating kamera dan rating umum smartphone:", correlation)
# Out:
# Korelasi antara rating kamera dan rating umum smartphone: 0.5620457343344627

# %% [markdown]
# 3. Menampilkan analisis deskriptif statistik / data outlier

# %%
df.describe()
# Out:
#                price  avg_rating   5G_or_not   num_cores  processor_speed  \
# count     980.000000  879.000000  980.000000  974.000000       938.000000
# mean    32520.504082    7.825825    0.560204    7.772074         2.427217
# std     39531.812669    0.740285    0.496616    0.836845         0.464090
# min      3499.000000    6.000000    0.000000    4.000000         1.200000
# 25%     12999.000000    7.400000    0.000000    8.000000         2.050000
# 50%     19994.500000    8.000000    1.000000    8.000000         2.300000
# 75%     35491.500000    8.400000    1.000000    8.000000         2.840000
# max    650000.000000    8.900000    1.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        969.000000               980.000000     769.000000    980.000000
# mean        4817.748194                 0.854082      46.126138      6.560204
# ...

# %% [markdown]
# data outlier

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#menggunakan Interquartile Range (IQR)
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
print("Data Outlier pada kolom 'price':")
print(outliers)

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['price'])
plt.title('Box Plot Harga Smartphone')
plt.xlabel('Harga')
plt.show()
# Out:
# Lower Bound: -20739.75
# Upper Bound: 69230.25
# Data Outlier pada kolom 'price':
#     brand_name                                   model   price  avg_rating  \
# 2        apple                 Apple iPhone 11 Pro Max  109900         7.7
# 9        apple             Apple iPhone 12 Pro (256GB)  119900         8.0
# 10       apple             Apple iPhone 12 Pro (512GB)  139900         8.0
# 12       apple                 Apple iPhone 13 (256GB)   72999         7.9
# 13       apple                 Apple iPhone 13 (512GB)   91999         8.0
# ..         ...                                     ...     ...         ...
# 857     xiaomi                      Xiaomi 13 Ultra 5G   71999         NaN
# 873     xiaomi                     Xiaomi Mi Mix Alpha  199990         NaN
# 874     xiaomi                      Xiaomi Mi Mix Fold  109990         NaN
# 875     xiaomi                    Xiaomi Mix Fold 2 5G  106990         NaN
# ...
